# %%
import numpy as np

# Set up matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

from astropy.io import fits

# %%
image_data = fits.getdata('/content/q10.fits')
print(type(image_data))
print(image_data.shape)
# Out:
# <class 'numpy.ndarray'>
# (300, 300)

# %%
plt.imshow(image_data, cmap='gray')
plt.colorbar()
